# %% [markdown]
# <a href="https://colab.research.google.com/github/supriyaohdar/Lung-Cancer-Prediction/blob/main/LungCancerPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lung cancer Prediction

# %% [markdown]
# #Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Uploading dataset

# %%
#from google.colab import files
#uploaded = files.upload()

# %% [markdown]
# #Loading datasets

# %%
data=pd.read_excel("datasets.xlsx")
data.head(20)
# Out:
#    Patient Id  Age  Gender  ...  Dry Cough  Snoring   Level
# 0          P1   33       1  ...          3        4     Low
# 1         P10   17       1  ...          7        2  Medium
# 2        P100   35       1  ...          7        2    High
# 3       P1000   37       1  ...          7        5    High
# 4        P101   46       1  ...          2        3    High
# 5        P102   35       1  ...          7        2    High
# 6        P103   52       2  ...          3        4     Low
# 7        P104   28       2  ...          4        3     Low
# 8        P105   35       2  ...          4        1  Medium
# 9        P106   46       1  ...          1        5  Medium
# 10       P107   44       1  ...          5        3    High
# 11       P108   64       2  ...          1        4    High
# 12       P109   39       2  ...          5        6  Medium
# 13        P11   34       1  ...          7        5    High
# 14       P110   27       2  ...          6        2     Low
# ...

# %%
data.describe(include="all")
# Out:
#        Patient Id          Age       Gender  ...    Dry Cough      Snoring  Level
# count        1000  1000.000000  1000.000000  ...  1000.000000  1000.000000   1000
# unique       1000          NaN          NaN  ...          NaN          NaN      3
# top            P4          NaN          NaN  ...          NaN          NaN   High
# freq            1          NaN          NaN  ...          NaN          NaN    365
# mean          NaN    37.174000     1.402000  ...     3.853000     2.926000    NaN
# std           NaN    12.005493     0.490547  ...     2.039007     1.474686    NaN
# min           NaN    14.000000     1.000000  ...     1.000000     1.000000    NaN
# 25%           NaN    27.750000     1.000000  ...     2.000000     2.000000    NaN
# 50%           NaN    36.000000     1.000000  ...     4.000000     3.000000    NaN
# 75%           NaN    45.000000     2.000000  ...     6.000000     4.000000    NaN
# ...

# %%
data.shape
# Out:
# (1000, 25)

# %%
data.dtypes
# Out:
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %% [markdown]
# #Dropping patient ID column

# %%
data.drop(columns=['Patient Id'], axis=1, inplace=True)
data.drop(columns=['Gender'], axis=1, inplace=True)
data.head()
# Out:
#    Age  Air Pollution  Alcohol use  ...  Dry Cough  Snoring   Level
# 0   33              2            4  ...          3        4     Low
# 1   17              3            1  ...          7        2  Medium
# 2   35              4            5  ...          7        2    High
# 3   37              7            7  ...          7        5    High
# 4   46              6            8  ...          2        3    High
#
# [5 rows x 23 columns]

# %%
data['Level'].value_counts()
# Out:
# High      365
# Medium    332
# Low       303
# Name: Level, dtype: int64

# %% [markdown]
# #Label encoding

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
data['Level']= label_encoder.fit_transform(data['Level'])
  
data.head(5)
# Out:
#    Age  Air Pollution  Alcohol use  ...  Dry Cough  Snoring  Level
# 0   33              2            4  ...          3        4      1
# 1   17              3            1  ...          7        2      2
# 2   35              4            5  ...          7        2      0
# 3   37              7            7  ...          7        5      0
# 4   46              6            8  ...          2        3      0
#
# [5 rows x 23 columns]

# %% [markdown]
# #Data visualization

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
data.shape
# Out:
# (1000, 23)

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=data['Age'], y=data['Level'])
plt.plot()
# Out:
# []

# %% [markdown]
# #Splitting the dataset

# %%
from sklearn.model_selection import train_test_split


array = data.values
X = array[:, 0:22]
Y = array[:, 22]

x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.20, random_state=1)

# %% [markdown]
# #Building the Model

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions1 = model.predict(x_valid)

# %%
score = model.score(x_valid, y_valid)
score
# Out:
# 1.0

# %%
acc = model.score(x_valid, y_valid)
acc*100
# Out:
# 100.0

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_valid, predictions1))
# Out:
# 0.0

# %% [markdown]
#  Kfold cross validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Test options and evaluation metric
num_folds = 10
seed = 7
scoring = 'accuracy'

kfold = KFold(n_splits=num_folds, random_state=seed)
cv_results = cross_val_score(model, x_train, y_train, scoring=scoring, cv=kfold)
msg = '%f (%f)'%(cv_results.mean(), cv_results.std())
print(msg)
# Out:
# 0.997500 (0.005000)
